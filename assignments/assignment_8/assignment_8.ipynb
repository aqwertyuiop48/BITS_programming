# %%
# !git clone https://github.com/aqwertyuiop48/BITS_programming.git /content/BITS_programming
# %cd /content/BITS_programming/assignments/assignment_8

# !pip install -r requirements.txt

# !python scripts/setup_baseline.py
# !python scripts/m8_l1_quantize_onnx.py
# !python scripts/m8_l2_benchmark.py
# Out:
# Cloning into '/content/BITS_programming'...
# remote: Enumerating objects: 1961, done.
# remote: Counting objects: 100% (617/617), done.
# remote: Compressing objects: 100% (411/411), done.
# remote: Total 1961 (delta 206), reused 486 (delta 124), pack-reused 1344 (from 3)
# Receiving objects: 100% (1961/1961), 264.30 MiB | 20.11 MiB/s, done.
# Resolving deltas: 100% (270/270), done.
# Updating files: 100% (1336/1336), done.
# /content/BITS_programming/assignments/assignment_8
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 46.4 MB/s eta 0:00:00
# ...
# Setting up baseline model...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 108MB/s]
# PyTorch model saved: 44.67 MB
# ONNX model saved: 44.58 MB
# Baseline PyTorch and ONNX models created in models/ folder.
# ...

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-09-08 20:46:45
